# %%
import time
import urllib
import urllib.request
from urllib.request import urlopen
import re
from http.cookiejar import CookieJar
import http.cookiejar
import datetime
import pprint

# %%
import time
import urllib
import urllib.request
from urllib.request import urlopen
import re
from http.cookiejar import CookieJar
import http.cookiejar
import datetime
import pprint


cj = CookieJar()
open = urllib.request.build_opener(urllib.request.HTTPCookieProcessor(cj))
page = 'http://www.imdb.com/title/tt2702724/reviews?start=0'
data = []
def main():
    for i in range(0,5):
        try:
            sourcecode = open.open(page).read()

            try:
                comments = re.findall(b'<b>Author:</b>(.*?)</p>', sourcecode,re.S)
                for comment in comments:
                    data.append(comment)
            except Exception as e:
                print (e)

        except Exception as e:
            print(e)
        page = "http://www.imdb.com/title/tt2702724/reviews?start="+str(i+11)
    print(data)
main()
# Out:
# local variable 'page' referenced before assignment
# [b'\n<a href="/user/ur66527028/">amanda</a> <small>from Arizona</small><br>\n<small>20 April 2016</small><br>\n\n</div>\n<p>\nSo dry. No humor whatsoever. Boring as heck. Sat through a full hour\nwaiting for the story to pick up. Weak story line and even weaker\ncomedy by the actors. So lame. So so so so so so lame. . MM is much\nbetter than this. Baffled as to how production companies picked this\ncrap up. She can do so much better. . I don&#x27;t understand why director\nwould pan out after a lame joke to a shot of the city, and zoom in,\nthis happened like 10 times. Why are these &#x27;filler scenes&#x27; necessary,\nmight it be because oh, there&#x27;s no HUMOR? I was sorely disappointed to\nsay the very least; even Kristen Bell disappointed me with her weak\nlines.\n', b'\n<a href="/user/ur43333638/">hp-anzinger</a><br>\n<small>20 April 2016</small><br>\n\n</div>\n<p>\nTV shows: Almost every year you see a new clever comedy show like\nScrubs, Simpsons, Big Bang Theory, Southpark, Malcolm in the Middle,\n... You don&#x27;t have to like it, but at least acknowledge that it is very\nclever and well written. <br><br>With movies on the other side it&#x27;s a different story. Here the trend is\nthat it is getting worse and worse. We are almost at a point where we\nwere in the 80&#x27;s.<br><br>The problem: The movies make money and as long as this is happening we\nwill see movies like &#x22;The Boss&#x22; in the future. Or another theory - I&#x27;m\ngetting to old for this kind of movies.\n', b'\n<a href="/user/ur64586503/">xinfatale</a> <small>from United States</small><br>\n<small>20 April 2016</small><br>\n\n</div>\n<p>\nI can&#x27;t believe I let my friend drag me into watching this ....\natrocious film.<br><br>This movie relies on ugly, immoral jokes that demean and pigeonhole\npeople into old fashioned stereotypes. Making fun of lesbians?\nSeriously who does that anymore?! Also, if the jokes are ugly and cheap\nto begin with, forcing child actors to say them doesn&#x27;t make the jokes\nany prettier. Slang terms and vulgar words do not automatically equal\nhumor. Far from it.<br><br>Absolutely tasteless.<br><br>The Boss lacked subtlety, and I found myself comparing Melissa\nMcCarthy&#x27;s role to Donald Trump, and not in a good way, mind you. There\nwas nothing funny about the film---the violent attempt at slapstick\nhumor failed. It was badly timed and came off rather flat. No one was\nlikable except Peter Dinklage&#x27;s role. Even then, he is shoved into a\nstereotype about funny midgets. What are we? 8 year old children? That\nwas the last time I ever laughed simply because someone was shorter\nthan average.<br><br>There is a way to mix violence/vulgarity to create a comedy (See\nDeadpool, Hot Fuzz, etc.), but The Boss definitely never even took off.\nJust pure failure.<br><br>Hated the film. I don&#x27;t recommend wasting your brain cells on this.\n', b'\n<a href="/user/ur19822838/">professorscott</a> <small>from Seattle</small><br>\n<small>13 April 2016</small><br>\n<p><b>*** This review may contain spoilers ***</b>', b'\n<a href="/user/ur66361639/">nra-05473</a> <small>from Central Valley CA</small><br>\n<small>11 April 2016</small><br>\n\n</div>\n<p>\nI was ready for a fun, entertaining comedy and it failed at every\nlevel. Melissa and her hubby should not ever collaborate on a venture\nagain, the writing and execution was forced which did not flow. We love\nMelissa, however she should have taken her concept to a professional\nwriter. Peter Dinklage did not deliver which was completely surprising\nconsidering his career performance with Game of Thrones. For the most\npart he looked like he was in pain in all his scenes. I&#x27;m sorry to say,\nit is not even worth a future video rental. This is the first review I\nhave written, I want to save you the pain! I wish I would have read\nreviews before spending my time and money. Let&#x27;s wish Melissa a better\nscript for any future movies, as this was a pure dud.\n' ...

# %%
for i in range(0,len(data)):
    data[i] = data[i].decode('UTF-8')

# %%
for i in range(0,len(data)):
    data[i] = re.sub(r'[^\w]', ' ', data[i])
    data[i] = (re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", data[i])).lower()

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
filteredData=[]
stopWords = set(stopwords.words('english'))
new_stopWords = set(['href','div','p','br'])
stopWords = stopWords|new_stopWords

for row in data:
    eachWord = word_tokenize(row)
    for i in eachWord:
        if i not in stopWords or len(i)>1:
            filteredData.append(i)

for i in filteredData:
    if i in new_stopWords or len(i)>1:
        filteredData.remove(i)

# %%
filteredData
# Out:
# ['amanda',
#  'dry',
#  'heck',
#  'hour',
#  'pick',
#  'weak',
#  'line',
#  'so',
#  'so',
#  'lame',
#  'companies',
#  'so',
#  'why',
#  'lame',
#  'city',
#  'zoom',
#  'why',
#  'these',
#  'filler',
#  'might',
#  'oh',
#  'sorely',
#  'weak',
#  'b',
#  'contain',
#  'b',
#  'nra',
#  'valley',
#  'ready',
#  'level',
#  'hubby',
#  'collaborate',
#  'venture',
#  'we',
#  'writer',
#  'scenes',
#  'sorry',
#  'say',
#  'rental',
#  'save',
#  'reviews',
#  'spending',
#  'money',
#  'pure',
#  'ur6458242',
#  'scenes',
#  'women',
#  'young',
#  'second',
#  'poorly',
#  'third',
#  'results',
#  'player',
#  'acting',
#  'guys',
#  'writer',
#  'ball',
#  'davis',
#  'stapleton',
#  'ryan',
#  'russell',
#  'allen',
#  'long',
#  'streisand',
#  'women',
#  'each',
#  'face',
#  'young',
#  'brawling',
#  'shows',
#  'stuff',
#  'hurtful',
#  'male',
#  'despises',
#  'promotion',
#  'conflicts',
#  'intensely',
#  'pushy',
#  'aggressive',
#  'physically',
#  'necessarily',
#  'qualities',
#  'lovable',
#  'warm',
#  'sensitive',
#  'personality',
#  'glass',
#  'three',
#  'mai',
#  'featuring',
#  'harold',
#  'about',
#  'sad',
#  'sadie',
#  'about',
#  'gomer',
#  'usmc',
#  'affable',
#  'slow',
#  'gina',
#  'vickie',
#  'about',
#  'updated',
#  'archie',
#  'edith',
#  'clueless',
#  'eddie',
#  'son',
#  'law',
#  'off',
#  'anything',
#  'ur56071541',
#  'scenes',
#  'got',
#  'lighted',
#  'groups',
#  'middle',
#  'scenes',
#  'snickered',
#  'trailer',
#  'overshadowed',
#  'where',
#  'wondering',
#  'purpose',
#  'aside',
#  'being',
#  'mother',
#  'michelle',
#  'b',
#  'contain',
#  'b',
#  'merril444',
#  'australia',
#  'wanted',
#  'total',
#  'enjoyed',
#  'bloopers',
#  'than',
#  'laugh',
#  'ridiculous',
#  'co',
#  'emotionally',
#  'mouthy',
#  'business',
#  'morals',
#  'cast',
#  'surprised',
#  'kathy',
#  'clever',
#  'save',
#  'money',
#  'essential',
#  'australia',
#  'forward',
#  'seeing',
#  'skills',
#  'spoiled',
#  'references',
#  'shouting',
#  'language',
#  'saddened',
#  'see',
#  'women',
#  'see',
#  'whole',
#  'so',
#  'been',
#  'improvement',
#  'missed',
#  'left',
#  'cinema',
#  'experience',
#  'discouraged',
#  'entertainment',
#  'language',
#  'cleaned',
#  'am',
#  'fashioned',
#  'ur43333638',
#  'hp',
#  'anzinger',
#  'tv',
#  'shows',
#  'almost',
#  'see',
#  'clever',
#  'scrubs',
#  'simpsons',
#  'big',
#  'bang',
#  'theory',
#  'southpark',
#  'malcolm',
#  'middle',
#  'acknowledge',
#  'clever',
#  'side',
#  'different',
#  'trend',
#  'we',
#  'almost',
#  'where',
#  'we',
#  'money',
#  'long',
#  'happening',
#  'we',
#  'see',
#  'x22',
#  'x22',
#  'another',
#  'theory',
#  'getting',
#  'kind',
#  'ur64586503',
#  'friend',
#  'watching',
#  'atrocious',
#  'relies',
#  'ugly',
#  'jokes',
#  'demean',
#  'pigeonhole',
#  'fashioned',
#  'stereotypes',
#  'fun',
#  'seriously',
#  'anymore',
#  'jokes',
#  'ugly',
#  'cheap',
#  'begin',
#  'forcing',
#  'actors',
#  'say',
#  'doesn',
#  'jokes',
#  'prettier',
#  'terms',
#  'vulgar',
#  'automatically',
#  'absolutely',
#  'lacked',
#  'myself',
#  'trump',
#  'mind',
#  'about',
#  'violent',
#  'humor',
#  'badly',
#  'off',
#  'flat',
#  'likable',
#  'except',
#  'role',
#  'then',
#  'shoved',
#  'stereotype',
#  'about',
#  'we',
#  'simply',
#  'than',
#  'mix',
#  'vulgarity',
#  'create',
#  'see',
#  'etc',
#  'definitely',
#  'even',
#  'off',
#  'pure',
#  'hated',
#  'wasting',
#  'brain',
#  'ur19822838',
#  'seattle',
#  'b',
#  'contain',
#  'b',
#  'nra',
#  'valley',
#  'ready',
#  'fun',
#  'comedy',
#  'at',
#  'level',
#  'hubby',
#  'collaborate',
#  'venture',
#  'we',
#  'writer',
#  'considering',
#  'like',
#  'he',
#  'scenes',
#  'sorry',
#  'say',
#  'even',
#  'rental',
#  'want',
#  'save',
#  'reviews',
#  'spending',
#  'time',
#  'money',
#  'better',
#  'future',
#  'pure',
#  'ur6458242',
#  'united',
#  'except',
#  'scenes',
#  'women',
#  'even',
#  'worse',
#  'young',
#  'second',
#  'poorly',
#  'third',
#  'movie',
#  'role',
#  'results',
#  'player',
#  'acting',
#  'like',
#  'guys',
#  'work',
#  'at',
#  'least',
#  'writer',
#  'ball',
#  'davis',
#  'stapleton',
#  'ryan',
#  'funny',
#  'russell',
#  'funny',
#  'allen',
#  'funny',
#  'long',
#  'funny',
#  'streisand',
#  'funny',
#  'funny',
#  'women',
#  'each',
#  'face',
#  'funny',
#  'young',
#  'brawling',
#  'funny',
#  'worse',
#  'movie',
#  'one',
#  'person',
#  'shows',
#  'stuff',
#  'hurtful',
#  'nasty',
#  'one',
#  'male',
#  'movie',
#  'funny',
#  'despises',
#  'used',
#  'promotion',
#  'then',
#  'conflicts',
#  'intensely',
#  'with',
#  'nasty',
#  'pushy',
#  'aggressive',
#  'physically',
#  'would',
#  'necessarily',
#  'no',
#  'qualities',
#  'make',
#  'lovable',
#  'warm',
#  'sensitive',
#  'or',
#  'even',
#  'personality',
#  'glass',
#  'funny',
#  'three',
#  'mai',
#  'or',
#  'about',
#  'movie',
#  'featuring',
#  'harold',
#  'or',
#  'about',
#  'movie',
#  'about',
#  'sad',
#  'sadie',
#  'or',
#  'about',
#  'gomer',
#  'usmc',
#  'affable',
#  'slow',
#  'gina',
#  'vickie',
#  'or',
#  'about',
#  'updated',
#  'with',
#  'archie',
#  'edith',
#  'into',
#  'clueless',
#  'eddie',
#  'into',
#  'son',
#  'into',
#  'daughter',
#  'law',
#  'off',
#  'anything',
#  'laugh',
#  'ur56071541',
#  'united',
#  'scenes',
#  'funny',
#  'got',
#  'lighted',
#  'no',
#  'laugh',
#  'groups',
#  'middle',
#  'funny',
#  'scenes',
#  'snickered',
#  'seen',
#  'trailer',
#  'funny',
#  'bell',
#  'overshadowed',
#  'where',
#  'wondering',
#  'purpose',
#  'aside',
#  'being',
#  'mother',
#  'one',
#  'very',
#  'movie',
#  'michelle',
#  'b',
#  'contain',
#  'b',
#  'user',
#  'merril444',
#  'australia',
#  'wanted',
#  'like',
#  'movie',
#  'really',
#  'like',
#  'total',
#  'time',
#  'enjoyed',
#  'bloopers',
#  'than',
#  'movie',
#  'at',
#  'least',
#  'made',
#  'laugh',
#  'ridiculous',
#  'very',
#  'funny',
#  'co',
#  'better',
#  'emotionally',
#  'mouthy',
#  'business',
#  'with',
#  'morals',
#  'cast',
#  'simply',
#  'stereotypes',
#  'surprised',
#  'kathy',
#  'bell',
#  'movie',
#  'clever',
#  'save',
#  'money',
#  'user',
#  'essential',
#  'australia',
#  'forward',
#  'seeing',
#  'seen',
#  'movies',
#  'comedic',
#  'sadly',
#  'very',
#  'with',
#  'sadly',
#  'way',
#  'skills',
#  'were',
#  'spoiled',
#  'references',
#  'shouting',
#  'with',
#  'language',
#  'saddened',
#  'see',
#  'women',
#  'at',
#  'funny',
#  'stay',
#  'see',
#  'whole',
#  'so',
#  'been',
#  'improvement',
#  'missed',
#  'as',
#  'left',
#  'cinema',
#  'experience',
#  'discouraged',
#  'work',
#  'entertainment',
#  'would',
#  'language',
#  'cleaned',
#  'am',
#  'fashioned',
#  'user',
#  'tylervirtual',
#  'united',
#  'small',
#  'div',
#  'misfire',
#  'with',
#  'movie',
#  'write',
#  'with',
#  'with',
#  'restricted',
#  'physical',
#  'humor',
#  'with',
#  'acting',
#  'is',
#  'lazy',
#  'at',
#  'comedy',
#  'with',
#  'jokes',
#  'weird',
#  'ending',
#  'feels',
#  'place',
#  'because',
#  'entire',
#  'movie',
#  'is',
#  'only',
#  'is',
#  'jokes',
#  'michelle',
#  'is',
#  'she',
#  'learn',
#  'is',
#  'intertwines',
#  'with',
#  'is',
#  'contrast',
#  'besides',
#  'is',
#  'made',
#  'movie',
#  'on',
#  'youtube',
#  'want',
#  'check',
#  'out',
#  'https',
#  'youtube',
#  'watch',
#  'v',
#  'user',
#  'ur64586503',
#  'xinfatale',
#  'small',
#  'united',
#  'small',
#  'small',
#  'small',
#  'div',
#  'can',
#  'believe',
#  'friend',
#  'drag',
#  'into',
#  'watching',
#  'atrocious',
#  'br',
#  'movie',
#  'relies',
#  'on',
#  'ugly',
#  'immoral',
#  'jokes',
#  'demean',
#  'pigeonhole',
#  'people',
#  'into',
#  'old',
#  'fashioned',
#  'stereotypes',
#  'making',
#  'fun',
#  'lesbians',
#  'seriously',
#  'anymore',
#  'jokes',
#  'ugly',
#  'cheap',
#  'begin',
#  'with',
#  'forcing',
#  'child',
#  'actors',
#  'say',
#  'doesn',
#  'make',
#  'jokes',
#  'any',
#  'prettier',
#  'slang',
#  'terms',
#  'vulgar',
#  'words',
#  'automatically',
#  'equal',
#  'humor',
#  'br',
#  'br',
#  'absolutely',
#  'tasteless',
#  'br',
#  'br',
#  'lacked',
#  'subtlety',
#  'found',
#  'myself',
#  'comparing',
#  'role',
#  'donald',
#  'trump',
#  'way',
#  'mind',
#  'there',
#  'funny',
#  'about',
#  'violent',
#  'at',
#  'slapstick',
#  'humor',
#  'badly',
#  'timed',
#  'came',
#  'off',
#  'flat',
#  'no',
#  'one',
#  'likable',
#  'except',
#  'peter',
#  'role',
#  'even',
#  'then',
#  'he',
#  'is',
#  'shoved',
#  'into',
#  'stereotype',
#  'about',
#  'funny',
#  'midgets',
#  'we',
#  'old',
#  'last',
#  'time',
#  'laughed',
#  'simply',
#  'because',
#  'someone',
#  'shorter',
#  'than',
#  'average',
#  'br',
#  'br',
#  'there',
#  'is',
#  'way',
#  'mix',
#  'violence',
#  'vulgarity',
#  'create',
#  'comedy',
#  'see',
#  'deadpool',
#  'fuzz',
#  'etc',
#  'but',
#  'definitely',
#  'even',
#  'took',
#  'off',
#  'pure',
#  'failure',
#  'br',
#  'br',
#  'hated',
#  'film',
#  'don',
#  'recommend',
#  'wasting',
#  'brain',
#  'cells',
#  'on',
#  'user',
#  'ur19822838',
#  'small',
#  'seattle',
#  'small',
#  'br',
#  'small',
#  'small',
#  'br',
#  'b',
#  'review',
#  'contain',
#  'b',
#  'user',
#  'nra',
#  'small',
#  'from',
#  'valley',
#  'small',
#  'br',
#  'small',
#  'april',
#  'small',
#  'br',
#  'div',
#  'ready',
#  'fun',
#  'comedy',
#  'at',
#  'level',
#  'hubby',
#  'not',
#  'collaborate',
#  'on',
#  'venture',
#  'and',
#  'not',
#  'we',
#  'however',
#  'she',
#  'have',
#  'writer',
#  'peter',
#  'dinklage',
#  'not',
#  'completely',
#  'considering',
#  'with',
#  'he',
#  'like',
#  'he',
#  'pain',
#  'in',
#  'all',
#  'scenes',
#  'sorry',
#  'say',
#  'is',
#  'not',
#  'even',
#  'future',
#  'rental',
#  'is',
#  'the',
#  'review',
#  'have',
#  'want',
#  'save',
#  'the',
#  'pain',
#  'wish',
#  'would',
#  'have',
#  'reviews',
#  'spending',
#  'time',
#  'and',
#  'money',
#  'let',
#  'wish',
#  'better',
#  'any',
#  'future',
#  'movies',
#  'as',
#  'pure',
#  'href',
#  'user',
#  'ur6458242',
#  'small',
#  'from',
#  'united',
#  'small',
#  'br',
#  'small',
#  'april',
#  'small',
#  'br',
#  'div',
#  'is',
#  'with',
#  'movie',
#  'the',
#  'should',
#  'is',
#  'not',
#  'with',
#  'movie',
#  'first',
#  'except',
#  'the',
#  'scenes',
#  'movie',
#  'is',
#  'not',
#  'funny',
#  'it',
#  'women',
#  'and',
#  'even',
#  'worse',
#  'young',
#  'is',
#  'not',
#  'funny',
#  'second',
#  'the',
#  'movie',
#  'is',
#  'poorly',
#  'third',
#  'the',
#  'movie',
#  'with',
#  'role',
#  'with',
#  'results',
#  'the',
#  'player',
#  'is',
#  'not',
#  'funny',
#  'she',
#  'is',
#  'loud',
#  'and',
#  'it',
#  'all',
#  'down',
#  'acting',
#  'like',
#  'nasty',
#  'guys',
#  'just',
#  'does',
#  'not',
#  'work',
#  'at',
#  'least',
#  'not',
#  'writer',
#  'ball',
#  'funny',
#  'davis',
#  'funny',
#  'stapleton',
#  'funny',
#  'ryan',
#  'funny',
#  'russell',
#  'funny',
#  'allen',
#  'was',
#  'funny',
#  'long',
#  'is',
#  'funny',
#  'streisand',
#  'is',
#  'funny',
#  'melissa',
#  'is',
#  'not',
#  'funny',
#  'women',
#  'each',
#  'other',
#  'in',
#  'the',
#  'face',
#  'is',
#  'not',
#  'funny',
#  'young',
#  'brawling',
#  'is',
#  'not',
#  'funny',
#  'worse',
#  'the',
#  'movie',
#  'one',
#  'the',
#  'is',
#  'person',
#  'and',
#  'shows',
#  'it',
#  'she',
#  'no',
#  'she',
#  'does',
#  'stuff',
#  'is',
#  'really',
#  'hurtful',
#  'and',
#  'nasty',
#  'the',
#  'one',
#  'male',
#  'in',
#  'movie',
#  'who',
#  'is',
#  'funny',
#  'despises',
#  'the',
#  'and',
#  'with',
#  'good',
#  'reason',
#  'she',
#  'used',
#  'him',
#  'promotion',
#  'and',
#  'then',
#  'him',
#  'all',
#  'the',
#  'conflicts',
#  'in',
#  'the',
#  'are',
#  'in',
#  'she',
#  'is',
#  'intensely',
#  'and',
#  'with',
#  'good',
#  'reason',
#  'the',
#  'is',
#  'nasty',
#  'she',
#  'is',
#  'pushy',
#  'loud',
#  'aggressive',
#  'and',
#  'physically',
#  'would',
#  'not',
#  ...]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
neg = []
pos = []
neu = []
compo = []

# %%
for word in filteredData:
    result = analyser.polarity_scores(word)
    neg.append(result['neg'])
    pos.append(result['pos'])
    neu.append(result['neu'])
    compo.append(result['compound'])

# %%
import numpy as np
data=[sum(np.array(neg)), sum(np.array(pos)), sum(np.array(neu)), sum(np.array(compo))]

# %%
def max(data):
    if data[0]>data[1]:
        return str(data[0])+" neg" 
    else:
        return str(data[1])+" pos"
a = max(data)
a
# Out:
# '253.0 pos'

# %%
import matplotlib.pyplot as plt

# %%
y=len(data)
x = np.arange(y)
width = 0.35
fig = plt.figure()
ax = fig.add_subplot(111)

# %%
xTickMarks=('neg', 'pos', 'neu', 'comp')
xtickNames = ax.set_xticklabels(xTickMarks)
ax.set_xticks(x+(width/2))
# Out:
# [<matplotlib.axis.XTick at 0x916aef0>,
#  <matplotlib.axis.XTick at 0x8e99eb0>,
#  <matplotlib.axis.XTick at 0x8d8bb90>,
#  <matplotlib.axis.XTick at 0x86c29d0>]

# %%
rects1 = ax.bar(x,data,width)
plt.show()
